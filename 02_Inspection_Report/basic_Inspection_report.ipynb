# %% [markdown]
# # Basic Dataset Inspection Report
#
# ## Customer Personality Analysis Dataset
#
# ### 1. Dataset Overview
#
# The Customer Personality Analysis dataset was successfully downloaded from Kaggle and stored in the **01_Raw_Data** folder. The dataset was imported into Python using the Pandas library and inspected to understand its structure before performing any preprocessing or analysis.
#
# ### 2. Basic Dataset Information
#
# | **Property**      | **Value**                                                             |
# | ----------------- | --------------------------------------------------------------------- |
# | Dataset Name      | Customer Personality Analysis                                         |
# | Number of Rows    | 2,240                                                                 |
# | Number of Columns | 29                                                                    |
# | File Type         | CSV (.csv)                                                            |
# | Dataset Size      | *215.03 KB* |
#
#
# ### 3. Initial Inspection
#
# The first five records of the dataset were displayed using the `head()` function to verify that the data had been loaded correctly. The dataset contains customer demographic information, purchasing behavior, campaign responses, and product spending details.
#
# The `shape()` function confirmed that the dataset contains **2,240 records** and **29 variables**.
#
# The `info()` function was used to inspect the data types of all variables and to identify whether any columns contained missing values.
#
# ### 4. Summary
#
# The dataset was loaded successfully without any file errors. It consists of customer-related information that can be used for customer segmentation, marketing analysis, and campaign performance evaluation. The inspection confirms that the dataset is suitable for further analysis, including data quality assessment, preprocessing, and exploratory data analysis.
#
# ### 5. Conclusion
#
# The initial dataset inspection has been completed successfully. The dataset structure, dimensions, and file properties have been verified. The next step will be a detailed inspection of each variable, including data types, descriptions, missing values, duplicate records, and data quality issues.
